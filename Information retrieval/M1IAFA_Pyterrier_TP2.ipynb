# %% [markdown]
# # Université Paul Sabatier
#
# M1IAFA - Recherche d'information
#
# **TP 2**
#
# Enseignants : Lynda Tamine et Jesús Lovón
#
# Notebook proposé par : José G. Moreno
#
#
# 2024
#
# ---
#
# 💡 Penser à développer des scripts et fonctions auxiliaires qui vont permettre réutiliser les commandes récurrentes dans ce TP et les prochains. Ceci aussi vous permettra de garder de bon pratique du code et faciliter vos débogages.
#
# ---
#
#
# ### Attention ❗❗ Pour la note du TP :
# 🚨 *Questions de code* : Remplir le code manquant dans les parties correspondantes (le code commenté bénéficie des meilleures notes).
#
# 🚨 *Questions ouvertes* : Ecrivez votre réponse textuelle sous forme de commentaires dans les cellules correspondantes.
#
# 🚨 *Laissez vos sorties* pour les cellules où vous écrivez le code. Les sorties vides (notebook ou cellules non exécutées) correspondent à 0 points.
#
# ---

# %% [markdown]
# # TP 2. Application de la RI pour la liaison référentielle

# %% [markdown]
# Une application des méthodes de RI est la liaison référentielle. Cette tâche consiste à trouver le lien entre une portion de texte et la page Wikipédia qui le représentent le mieux. Dans ce cas d’application :
# * Comme requêtes nous allons utiliser chaque mot dans une phrase (ou chaque mot important).
# * Le corpus sont les pages Wikipédia. Donc, chaque page Wikipédia est un document à retrouver.
# * La liste de résultats sont les candidats pour la liaison référentielle.
#
# Considère par exemple la chaîne de caractères « ***Thomas and Mario are strikers playing in Munich*** ». Il existe trois sous-chaînes (***Thomas***, ***Mario*** et ***Munich***) ou mots importants qui sont susceptibles d'être identifiées dans une base de connaissances telle que Wikipédia. Une recherche de ces mots-clés dans les pages Wikipédia produirait de nombreux concepts candidats pour ces sous-chaînes. Donc un bon système doit retrouver comme premier résultats les liens aux pages Wikipédia : [Thomas Müller](https://en.wikipedia.org/wiki/Thomas_M%C3%BCller), [Mario Gómez](https://en.wikipedia.org/wiki/Mario_G%C3%B3mez) (ou Mario Götze) et FC [Bayern Munich](https://en.wikipedia.org/wiki/FC_Bayern_Munich). Cette tâche est particulièrement complexe et les méthodes de recherche d’information sont particulièrement utiles pour la résoudre.

# %% [markdown]
# > Plusieurs méthodes de liaison référentielle (Entity Linking en anglais) sont disponibles sur internet. Les plus connus sont :
#
# >	* Spotlight → https://demo.dbpedia-spotlight.org/
# >	* Babelfy → http://babelfy.org/
# >	* TagMe → https://tagme.d4science.org/tagme/

# %% [markdown]
# Étapes à suivre pendant ce TP :
# 1. Liaison avec le texte
# 2. Les poids
# 3. Utilisation de termes
# 4. Le titre
# 5. L'outil

# %% [markdown]
# ## 0. Installation de l’environnement de travail
#
# Installation et configuration de librairies comment le TP précédent.

# %%
# déclaration de la variable JAVA_HOME
import os
os.environ['JAVA_HOME'] = '/usr/lib/jvm/java-11-openjdk-amd64'
# !export JAVA_HOME=/usr/lib/jvm/java-11-openjdk-amd64

# %%
#installation de pyterrier avec pip
# !pip install --upgrade git+https://github.com/terrier-org/pyterrier.git#egg=python-terrier
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting python-terrier
#   Cloning https://github.com/terrier-org/pyterrier.git to /tmp/pip-install-jjnyu35c/python-terrier_3688056058df471aac59ba237fcf7e44
#   Running command git clone --filter=blob:none --quiet https://github.com/terrier-org/pyterrier.git /tmp/pip-install-jjnyu35c/python-terrier_3688056058df471aac59ba237fcf7e44
#   Resolved https://github.com/terrier-org/pyterrier.git to commit 81f20bda483f6044bda89f717ae863e62bab42e5
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: chest in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (0.2.3)
# Requirement already satisfied: deprecated in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (1.2.14)
# Requirement already satisfied: dill in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (0.3.7)
# Requirement already satisfied: ir_datasets>=0.3.2 in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (0.5.6)
# Requirement already satisfied: ir_measures>=0.3.1 in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (0.3.3)
# Requirement already satisfied: jinja2 in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (3.1.2)
# Requirement already satisfied: joblib in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (1.3.2)
# Requirement already satisfied: matchpy in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: more_itertools in /usr/lib/python3/dist-packages (from python-terrier) (8.10.0)
# Requirement already satisfied: nptyping==1.4.4 in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (1.4.4)
# Requirement already satisfied: numpy in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (1.23.5)
# Requirement already satisfied: pandas in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (2.1.4)
# Requirement already satisfied: pyjnius>=1.4.2 in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (1.6.1)
# Requirement already satisfied: pytrec_eval_terrier>=0.5.3 in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (0.5.6)
# Requirement already satisfied: requests in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (2.31.0)
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (from python-terrier) (1.8.0)
# Requirement already satisfied: statsmodels in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (0.14.1)
# Requirement already satisfied: tqdm in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (4.66.1)
# Requirement already satisfied: wget in /home/wadie/.local/lib/python3.10/site-packages (from python-terrier) (3.2)
# Requirement already satisfied: typish>=1.7.0 in /home/wadie/.local/lib/python3.10/site-packages (from nptyping==1.4.4->python-terrier) (1.9.3)
# Requirement already satisfied: ijson>=3.1.3 in /home/wadie/.local/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (3.2.3)
# Requirement already satisfied: lz4>=3.1.10 in /home/wadie/.local/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (4.3.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/lib/python3/dist-packages (from ir_datasets>=0.3.2->python-terrier) (5.4.1)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /home/wadie/.local/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: lxml>=4.5.2 in /home/wadie/.local/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (5.1.0)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /home/wadie/.local/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.1.12)
# Requirement already satisfied: warc3-wet>=0.2.3 in /home/wadie/.local/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied: unlzw3>=0.2.1 in /home/wadie/.local/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.2.2)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/lib/python3/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.10.0)
# Requirement already satisfied: inscriptis>=2.2.0 in /home/wadie/.local/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (2.4.0.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /home/wadie/.local/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: zlib-state>=0.1.3 in /home/wadie/.local/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.1.6)
# Requirement already satisfied: cwl-eval>=1.0.10 in /home/wadie/.local/lib/python3.10/site-packages (from ir_measures>=0.3.1->python-terrier) (1.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wadie/.local/lib/python3.10/site-packages (from requests->python-terrier) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/wadie/.local/lib/python3.10/site-packages (from requests->python-terrier) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->python-terrier) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/wadie/.local/lib/python3.10/site-packages (from requests->python-terrier) (3.3.2)
# Requirement already satisfied: heapdict in /home/wadie/.local/lib/python3.10/site-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/wadie/.local/lib/python3.10/site-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/wadie/.local/lib/python3.10/site-packages (from jinja2->python-terrier) (2.1.3)
# Requirement already satisfied: multiset<3.0,>=2.0 in /home/wadie/.local/lib/python3.10/site-packages (from matchpy->python-terrier) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/wadie/.local/lib/python3.10/site-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/wadie/.local/lib/python3.10/site-packages (from pandas->python-terrier) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->python-terrier) (2022.1)
# Requirement already satisfied: packaging>=21.3 in /home/wadie/.local/lib/python3.10/site-packages (from statsmodels->python-terrier) (23.2)
# Requirement already satisfied: patsy>=0.5.4 in /home/wadie/.local/lib/python3.10/site-packages (from statsmodels->python-terrier) (0.5.6)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.4->statsmodels->python-terrier) (1.16.0)
# Requirement already satisfied: cbor>=1.0.0 in /home/wadie/.local/lib/python3.10/site-packages (from trec-car-tools>=2.5.4->ir_datasets>=0.3.2->python-terrier) (1.0.0)

# %%
#Initialization de JVM
import pyterrier as pt
if not pt.started():
  pt.init()
# Out:
# PyTerrier 0.10.0 has loaded Terrier 5.8 (built by craigm on 2023-11-01 18:05) and terrier-helper 0.0.8
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.

# %% [markdown]
# ### Lecture d'un index existant.
#
# Ajoutez le code pour charger l'index créé sur **text** dans le TP 1.

# %%
# 1. Ajoutez votre pd_index.zip du TP1 à Google Colab

# 2. Changer NOM REPERTOIRE par le nom de votre dossier. Après exécuté la commande suivante
# !unzip -o pd_index.zip
# Out:
# Archive:  pd_index.zip
#   inflating: pd_index/data.meta-0.fsomapfile
#   inflating: pd_index/data.lexicon.fsomaphash
#   inflating: pd_index/data.inverted.bf
#   inflating: pd_index/data.document.fsarrayfile
#   inflating: pd_index/data.direct.bf
#   inflating: pd_index/data.lexicon.fsomapid
#   inflating: pd_index/data.meta.idx
#   inflating: pd_index/data.lexicon.fsomapfile
#   inflating: pd_index/data.meta.zdata
#   inflating: pd_index/data.properties

# %%
# To create an IndexRef to an existing index
indexref2 = pt.IndexRef.of("./pd_index/data.properties")

# %% [markdown]
# # 1) Liaison avec le texte
# En utilisant l’indexe du champ **text** de Wikipédia (comme dans le TP1) et la requête *« Thomas and Mario are strikers playing in Munich »* vérifiez si vous obtenez les pages Wikipédia respectives (comme le feraient Spotlight, Babelfy ou TagMe) :
# * Thomas Müller
# * Mario Gómez ou Mario Götze
# * FC Bayern Munich
#
# Voici la requete sur l'index mentionné :

# %%
pt.BatchRetrieve(indexref2, wmodel="BM25", metadata=["docno","title","url"]).search("Thomas and Mario are strikers playing in Munich").head(50)
# Out:
#    qid   docid   docno                               title  \
# 0    1   28330  114620              Mario Strikers Charged
# 1    1   28329  114619                Mario Smash Football
# 2    1   71587  303588                       Audi Cup 2013
# 3    1   15782   60424                         Donkey Kong
# 4    1   13712   50727                      Princess Daisy
# 5    1  166504  771849                     Mario Balotelli
# 6    1    1074    4029                               Yoshi
# 7    1   13711   50725                      Princess Peach
# 8    1  113762  509811                       Audi Cup 2015
# 9    1   74872  321537                   Alexander Zickler
# 10   1  123459  575949                        Tobias Kempe
# 11   1    7608   24698                               Luigi
# 12   1   23374   89790                               Wario
# 13   1    1066    4016                               Mario
# 14   1   49028  176951                         David Villa
# 15   1   80432  349023                   201011 Bundesliga
# 16   1   80536  349533                   201112 Bundesliga
# 17   1  203375  901670                                 Phl
# 18   1  105314  458489                  Robert Lewandowski
# 19   1   93934  409469                    Charles Martinet
# 20   1   88436  383264                Mario Kart Arcade GP
# 21   1  113888  510362                 Stephan Beckenbauer
# 22   1   50168  181294                           Uli Hoene
# 23   1   96296  418172               Mario vs. Donkey Kong
# 24   1   88504  383601                  Mario Pinball Land
# 25   1  130855  617049                   Super Mario Maker
# 26   1   88355  382951             New Super Mario Bros. U
# 27   1  198725  885321                         Hohenlinden
# 28   1  186668  839449                Super Mario Bros. 35
# 29   1  201546  895457                      Luan Rodrigues
# 30   1   91475  399539                       Mario Party 8
# 31   1  186619  839196         Fortune Street (video game)
# 32   1  129217  607474                         Fritz Egner
# 33   1   90108  391634                       Mario Party 4
# 34   1    2720    8577                       Mario Party 6
# 35   1   60720  247372                        Thomas Mller
# 36   1   54533  206801                         Paper Mario
# 37   1   91476  399545                       Mario Party 7
# 38   1  171156  787634  Super Mario Bros. 35th Anniversary
# 39   1   59794  242678                         Super Mario
# 40   1  182274  824105               Mario Slam Basketball
# 41   1   27553  111365           Mario Kart: Super Circuit
# 42   1  197370  879835                        Bernd Nickel
# 43   1   73386  314467                       SVG Reichenau
# 44   1   68999  293186                     Gerhard Tremmel
# 45   1   52656  195267                          Gary Twigg
# 46   1   55514  213649                       Marcel Schfer
# 47   1   88604  384261                       Mario Party 3
# 48   1   98469  429590                        Dr. Mario 64
# 49   1   98136  428138                          Bowser Jr.
#
#                                                   url  rank      score  \
# 0   https://simple.wikipedia.org/wiki/Mario%20Stri...     0  30.771667
# 1   https://simple.wikipedia.org/wiki/Mario%20Smas...     1  30.306808
# 2   https://simple.wikipedia.org/wiki/Audi%20Cup%2...     2  29.796582
# 3     https://simple.wikipedia.org/wiki/Donkey%20Kong     3  28.570535
# 4   https://simple.wikipedia.org/wiki/Princess%20D...     4  28.192863
# 5   https://simple.wikipedia.org/wiki/Mario%20Balo...     5  27.400834
# 6             https://simple.wikipedia.org/wiki/Yoshi     6  25.804927
# 7   https://simple.wikipedia.org/wiki/Princess%20P...     7  25.073465
# 8   https://simple.wikipedia.org/wiki/Audi%20Cup%2...     8  24.388908
# 9   https://simple.wikipedia.org/wiki/Alexander%20...     9  23.780821
# 10   https://simple.wikipedia.org/wiki/Tobias%20Kempe    10  23.603799
# 11            https://simple.wikipedia.org/wiki/Luigi    11  22.692159
# 12            https://simple.wikipedia.org/wiki/Wario    12  21.020281
# 13            https://simple.wikipedia.org/wiki/Mario    13  20.935477
# 14    https://simple.wikipedia.org/wiki/David%20Villa    14  20.862224
# 15  https://simple.wikipedia.org/wiki/2010%E2%80%9...    15  20.755765
# 16  https://simple.wikipedia.org/wiki/2011%E2%80%9...    16  20.655217
# 17        https://simple.wikipedia.org/wiki/P%C3%A4hl    17  20.533782
# 18  https://simple.wikipedia.org/wiki/Robert%20Lew...    18  20.356859
# 19  https://simple.wikipedia.org/wiki/Charles%20Ma...    19  19.695213
# 20  https://simple.wikipedia.org/wiki/Mario%20Kart...    20  19.566381
# 21  https://simple.wikipedia.org/wiki/Stephan%20Be...    21  19.550553
# 22  https://simple.wikipedia.org/wiki/Uli%20Hoene%...    22  19.543601
# 23  https://simple.wikipedia.org/wiki/Mario%20vs.%...    23  19.542285
# 24  https://simple.wikipedia.org/wiki/Mario%20Pinb...    24  19.319084
# 25  https://simple.wikipedia.org/wiki/Super%20Mari...    25  19.296400
# 26  https://simple.wikipedia.org/wiki/New%20Super%...    26  19.263808
# 27      https://simple.wikipedia.org/wiki/Hohenlinden    27  19.197015
# 28  https://simple.wikipedia.org/wiki/Super%20Mari...    28  19.140112
# 29  https://simple.wikipedia.org/wiki/Luan%20Rodri...    29  19.071240
# 30  https://simple.wikipedia.org/wiki/Mario%20Part...    30  19.038564
# 31  https://simple.wikipedia.org/wiki/Fortune%20St...    31  18.971374
# 32    https://simple.wikipedia.org/wiki/Fritz%20Egner    32  18.924370
# 33  https://simple.wikipedia.org/wiki/Mario%20Part...    33  18.877112
# 34  https://simple.wikipedia.org/wiki/Mario%20Part...    34  18.831535
# 35  https://simple.wikipedia.org/wiki/Thomas%20M%C...    35  18.725876
# 36    https://simple.wikipedia.org/wiki/Paper%20Mario    36  18.695550
# 37  https://simple.wikipedia.org/wiki/Mario%20Part...    37  18.679694
# 38  https://simple.wikipedia.org/wiki/Super%20Mari...    38  18.664973
# 39    https://simple.wikipedia.org/wiki/Super%20Mario    39  18.554873
# 40  https://simple.wikipedia.org/wiki/Mario%20Slam...    40  18.548969
# 41  https://simple.wikipedia.org/wiki/Mario%20Kart...    41  18.482298
# 42   https://simple.wikipedia.org/wiki/Bernd%20Nickel    42  18.480602
# 43  https://simple.wikipedia.org/wiki/SVG%20Reichenau    43  18.478638
# 44  https://simple.wikipedia.org/wiki/Gerhard%20Tr...    44  18.477631
# 45     https://simple.wikipedia.org/wiki/Gary%20Twigg    45  18.390747
# 46  https://simple.wikipedia.org/wiki/Marcel%20Sch...    46  18.332757
# 47  https://simple.wikipedia.org/wiki/Mario%20Part...    47  18.321284
# 48  https://simple.wikipedia.org/wiki/Dr.%20Mario%...    48  18.281506
# 49     https://simple.wikipedia.org/wiki/Bowser%20Jr.    49  18.236685
#
#                                               query
# 0   Thomas and Mario are strikers playing in Munich
# 1   Thomas and Mario are strikers playing in Munich
# 2   Thomas and Mario are strikers playing in Munich
# 3   Thomas and Mario are strikers playing in Munich
# 4   Thomas and Mario are strikers playing in Munich
# 5   Thomas and Mario are strikers playing in Munich
# 6   Thomas and Mario are strikers playing in Munich
# 7   Thomas and Mario are strikers playing in Munich
# 8   Thomas and Mario are strikers playing in Munich
# 9   Thomas and Mario are strikers playing in Munich
# 10  Thomas and Mario are strikers playing in Munich
# 11  Thomas and Mario are strikers playing in Munich
# 12  Thomas and Mario are strikers playing in Munich
# 13  Thomas and Mario are strikers playing in Munich
# 14  Thomas and Mario are strikers playing in Munich
# 15  Thomas and Mario are strikers playing in Munich
# 16  Thomas and Mario are strikers playing in Munich
# 17  Thomas and Mario are strikers playing in Munich
# 18  Thomas and Mario are strikers playing in Munich
# 19  Thomas and Mario are strikers playing in Munich
# 20  Thomas and Mario are strikers playing in Munich
# 21  Thomas and Mario are strikers playing in Munich
# 22  Thomas and Mario are strikers playing in Munich
# 23  Thomas and Mario are strikers playing in Munich
# 24  Thomas and Mario are strikers playing in Munich
# 25  Thomas and Mario are strikers playing in Munich
# 26  Thomas and Mario are strikers playing in Munich
# 27  Thomas and Mario are strikers playing in Munich
# 28  Thomas and Mario are strikers playing in Munich
# 29  Thomas and Mario are strikers playing in Munich
# 30  Thomas and Mario are strikers playing in Munich
# 31  Thomas and Mario are strikers playing in Munich
# 32  Thomas and Mario are strikers playing in Munich
# 33  Thomas and Mario are strikers playing in Munich
# 34  Thomas and Mario are strikers playing in Munich
# 35  Thomas and Mario are strikers playing in Munich
# 36  Thomas and Mario are strikers playing in Munich
# 37  Thomas and Mario are strikers playing in Munich
# 38  Thomas and Mario are strikers playing in Munich
# 39  Thomas and Mario are strikers playing in Munich
# 40  Thomas and Mario are strikers playing in Munich
# 41  Thomas and Mario are strikers playing in Munich
# 42  Thomas and Mario are strikers playing in Munich
# 43  Thomas and Mario are strikers playing in Munich
# 44  Thomas and Mario are strikers playing in Munich
# 45  Thomas and Mario are strikers playing in Munich
# 46  Thomas and Mario are strikers playing in Munich
# 47  Thomas and Mario are strikers playing in Munich
# 48  Thomas and Mario are strikers playing in Munich
# 49  Thomas and Mario are strikers playing in Munich

# %% [markdown]
# ....
#
# Seul Thomas mller est présent dans les résultats
# Les deux autres ne font pas parties
#
# ....

# %% [markdown]
# # 2) Les poids
#
# Utilisez les différentes méthodes de pondération prédéfinies sur Pyterrier (http://terrier.org/docs/v5.2/javadoc/org/terrier/matching/models/package-summary.html) pour voir s’il existe des méthodes que vous donnent de meilleurs résultats.
#
# Choisir 5 méthodes (à vous de décider lesquels) et les comparer.
#
# C’est-à-dire inspectez les 10 premiers résultats et vérifiez si les pages d’intérêt (Thomas Müller, Mario Gómez ou Mario Götze et FC Bayern Munich) font partie des résultats, puis les 20 premiers, et finalement les 50 premiers. Existent-ils de différences importantes ?

# %%
pt.BatchRetrieve(indexref2, wmodel="PL2", metadata=["docno","title","url"]).search("Thomas and Mario are strikers playing in Munich").head(50)
# Out:
#    qid   docid   docno                               title  \
# 0    1   28330  114620              Mario Strikers Charged
# 1    1   28329  114619                Mario Smash Football
# 2    1   71587  303588                       Audi Cup 2013
# 3    1   13712   50727                      Princess Daisy
# 4    1   15782   60424                         Donkey Kong
# 5    1   13711   50725                      Princess Peach
# 6    1    1074    4029                               Yoshi
# 7    1  166504  771849                     Mario Balotelli
# 8    1  113762  509811                       Audi Cup 2015
# 9    1  123459  575949                        Tobias Kempe
# 10   1    7608   24698                               Luigi
# 11   1   49028  176951                         David Villa
# 12   1   74872  321537                   Alexander Zickler
# 13   1   23374   89790                               Wario
# 14   1    1066    4016                               Mario
# 15   1  113888  510362                 Stephan Beckenbauer
# 16   1  203375  901670                                 Phl
# 17   1   61624  252651                      Rumble Fighter
# 18   1  201546  895457                      Luan Rodrigues
# 19   1   47207  165793                          Bundesliga
# 20   1    8128   27025                         Gilli-danda
# 21   1  197370  879835                        Bernd Nickel
# 22   1   93934  409469                    Charles Martinet
# 23   1   68999  293186                     Gerhard Tremmel
# 24   1   52656  195267                          Gary Twigg
# 25   1  105314  458489                  Robert Lewandowski
# 26   1   80432  349023                   201011 Bundesliga
# 27   1   55514  213649                       Marcel Schfer
# 28   1   96296  418172               Mario vs. Donkey Kong
# 29   1   88436  383264                Mario Kart Arcade GP
# 30   1  116414  527506                        Klaas Bakker
# 31   1  198725  885321                         Hohenlinden
# 32   1   80536  349533                   201112 Bundesliga
# 33   1     576    2917                              Munich
# 34   1   59794  242678                         Super Mario
# 35   1   98136  428138                          Bowser Jr.
# 36   1  143954  687624            Jean-Claude Schindelholz
# 37   1   56923  221228                      Anthony Stokes
# 38   1  104184  454910                      Enner Valencia
# 39   1  197137  878436                    Pierre Kerkhoffs
# 40   1   88355  382951             New Super Mario Bros. U
# 41   1  129217  607474                         Fritz Egner
# 42   1  130855  617049                   Super Mario Maker
# 43   1   88504  383601                  Mario Pinball Land
# 44   1  171156  787634  Super Mario Bros. 35th Anniversary
# 45   1  143943  687595                         Fritz Knzli
# 46   1   50168  181294                           Uli Hoene
# 47   1  122605  569592                   Theo Brokmann Jr.
# 48   1  156497  745855                      Emilio Caprile
# 49   1  199428  888424                      Sandy Iannella
#
#                                                   url  rank      score  \
# 0   https://simple.wikipedia.org/wiki/Mario%20Stri...     0  14.949048
# 1   https://simple.wikipedia.org/wiki/Mario%20Smas...     1  14.685239
# 2   https://simple.wikipedia.org/wiki/Audi%20Cup%2...     2  13.851380
# 3   https://simple.wikipedia.org/wiki/Princess%20D...     3  13.785998
# 4     https://simple.wikipedia.org/wiki/Donkey%20Kong     4  13.560615
# 5   https://simple.wikipedia.org/wiki/Princess%20P...     5  12.622423
# 6             https://simple.wikipedia.org/wiki/Yoshi     6  12.323815
# 7   https://simple.wikipedia.org/wiki/Mario%20Balo...     7  12.071344
# 8   https://simple.wikipedia.org/wiki/Audi%20Cup%2...     8  11.598371
# 9    https://simple.wikipedia.org/wiki/Tobias%20Kempe     9  11.100438
# 10            https://simple.wikipedia.org/wiki/Luigi    10  11.006623
# 11    https://simple.wikipedia.org/wiki/David%20Villa    11  10.976695
# 12  https://simple.wikipedia.org/wiki/Alexander%20...    12  10.863448
# 13            https://simple.wikipedia.org/wiki/Wario    13  10.422862
# 14            https://simple.wikipedia.org/wiki/Mario    14  10.345671
# 15  https://simple.wikipedia.org/wiki/Stephan%20Be...    15  10.200467
# 16        https://simple.wikipedia.org/wiki/P%C3%A4hl    16   9.884370
# 17  https://simple.wikipedia.org/wiki/Rumble%20Fig...    17   9.794407
# 18  https://simple.wikipedia.org/wiki/Luan%20Rodri...    18   9.613205
# 19       https://simple.wikipedia.org/wiki/Bundesliga    19   9.587888
# 20      https://simple.wikipedia.org/wiki/Gilli-danda    20   9.469636
# 21   https://simple.wikipedia.org/wiki/Bernd%20Nickel    21   9.435757
# 22  https://simple.wikipedia.org/wiki/Charles%20Ma...    22   9.414146
# 23  https://simple.wikipedia.org/wiki/Gerhard%20Tr...    23   9.404492
# 24     https://simple.wikipedia.org/wiki/Gary%20Twigg    24   9.364864
# 25  https://simple.wikipedia.org/wiki/Robert%20Lew...    25   9.280083
# 26  https://simple.wikipedia.org/wiki/2010%E2%80%9...    26   9.274568
# 27  https://simple.wikipedia.org/wiki/Marcel%20Sch...    27   9.193279
# 28  https://simple.wikipedia.org/wiki/Mario%20vs.%...    28   9.103246
# 29  https://simple.wikipedia.org/wiki/Mario%20Kart...    29   9.047658
# 30   https://simple.wikipedia.org/wiki/Klaas%20Bakker    30   9.044231
# 31      https://simple.wikipedia.org/wiki/Hohenlinden    31   9.039395
# 32  https://simple.wikipedia.org/wiki/2011%E2%80%9...    32   9.016780
# 33           https://simple.wikipedia.org/wiki/Munich    33   9.009060
# 34    https://simple.wikipedia.org/wiki/Super%20Mario    34   8.984831
# 35     https://simple.wikipedia.org/wiki/Bowser%20Jr.    35   8.980601
# 36  https://simple.wikipedia.org/wiki/Jean-Claude%...    36   8.978994
# 37  https://simple.wikipedia.org/wiki/Anthony%20St...    37   8.972154
# 38  https://simple.wikipedia.org/wiki/Enner%20Vale...    38   8.958990
# 39  https://simple.wikipedia.org/wiki/Pierre%20Ker...    39   8.931815
# 40  https://simple.wikipedia.org/wiki/New%20Super%...    40   8.881128
# 41    https://simple.wikipedia.org/wiki/Fritz%20Egner    41   8.877512
# 42  https://simple.wikipedia.org/wiki/Super%20Mari...    42   8.863825
# 43  https://simple.wikipedia.org/wiki/Mario%20Pinb...    43   8.861202
# 44  https://simple.wikipedia.org/wiki/Super%20Mari...    44   8.859891
# 45  https://simple.wikipedia.org/wiki/Fritz%20K%C3...    45   8.840627
# 46  https://simple.wikipedia.org/wiki/Uli%20Hoene%...    46   8.794272
# 47  https://simple.wikipedia.org/wiki/Theo%20Brokm...    47   8.793633
# 48  https://simple.wikipedia.org/wiki/Emilio%20Cap...    48   8.785008
# 49  https://simple.wikipedia.org/wiki/Sandy%20Iann...    49   8.785008
#
#                                               query
# 0   Thomas and Mario are strikers playing in Munich
# 1   Thomas and Mario are strikers playing in Munich
# 2   Thomas and Mario are strikers playing in Munich
# 3   Thomas and Mario are strikers playing in Munich
# 4   Thomas and Mario are strikers playing in Munich
# 5   Thomas and Mario are strikers playing in Munich
# 6   Thomas and Mario are strikers playing in Munich
# 7   Thomas and Mario are strikers playing in Munich
# 8   Thomas and Mario are strikers playing in Munich
# 9   Thomas and Mario are strikers playing in Munich
# 10  Thomas and Mario are strikers playing in Munich
# 11  Thomas and Mario are strikers playing in Munich
# 12  Thomas and Mario are strikers playing in Munich
# 13  Thomas and Mario are strikers playing in Munich
# 14  Thomas and Mario are strikers playing in Munich
# 15  Thomas and Mario are strikers playing in Munich
# 16  Thomas and Mario are strikers playing in Munich
# 17  Thomas and Mario are strikers playing in Munich
# 18  Thomas and Mario are strikers playing in Munich
# 19  Thomas and Mario are strikers playing in Munich
# 20  Thomas and Mario are strikers playing in Munich
# 21  Thomas and Mario are strikers playing in Munich
# 22  Thomas and Mario are strikers playing in Munich
# 23  Thomas and Mario are strikers playing in Munich
# 24  Thomas and Mario are strikers playing in Munich
# 25  Thomas and Mario are strikers playing in Munich
# 26  Thomas and Mario are strikers playing in Munich
# 27  Thomas and Mario are strikers playing in Munich
# 28  Thomas and Mario are strikers playing in Munich
# 29  Thomas and Mario are strikers playing in Munich
# 30  Thomas and Mario are strikers playing in Munich
# 31  Thomas and Mario are strikers playing in Munich
# 32  Thomas and Mario are strikers playing in Munich
# 33  Thomas and Mario are strikers playing in Munich
# 34  Thomas and Mario are strikers playing in Munich
# 35  Thomas and Mario are strikers playing in Munich
# 36  Thomas and Mario are strikers playing in Munich
# 37  Thomas and Mario are strikers playing in Munich
# 38  Thomas and Mario are strikers playing in Munich
# 39  Thomas and Mario are strikers playing in Munich
# 40  Thomas and Mario are strikers playing in Munich
# 41  Thomas and Mario are strikers playing in Munich
# 42  Thomas and Mario are strikers playing in Munich
# 43  Thomas and Mario are strikers playing in Munich
# 44  Thomas and Mario are strikers playing in Munich
# 45  Thomas and Mario are strikers playing in Munich
# 46  Thomas and Mario are strikers playing in Munich
# 47  Thomas and Mario are strikers playing in Munich
# 48  Thomas and Mario are strikers playing in Munich
# 49  Thomas and Mario are strikers playing in Munich

# %%
pt.BatchRetrieve(indexref2, wmodel="DLH", metadata=["docno","title","url"]).search("Thomas and Mario are strikers playing in Munich").head(50)
# Out:
#    qid   docid   docno                     title  \
# 0    1   28330  114620    Mario Strikers Charged
# 1    1   28329  114619      Mario Smash Football
# 2    1   71587  303588             Audi Cup 2013
# 3    1   74872  321537         Alexander Zickler
# 4    1   13712   50727            Princess Daisy
# 5    1   15782   60424               Donkey Kong
# 6    1   13711   50725            Princess Peach
# 7    1    1074    4029                     Yoshi
# 8    1  166504  771849           Mario Balotelli
# 9    1    7608   24698                     Luigi
# 10   1   23374   89790                     Wario
# 11   1  123459  575949              Tobias Kempe
# 12   1  113762  509811             Audi Cup 2015
# 13   1    1066    4016                     Mario
# 14   1   49028  176951               David Villa
# 15   1  105314  458489        Robert Lewandowski
# 16   1   93934  409469          Charles Martinet
# 17   1   80432  349023         201011 Bundesliga
# 18   1   50168  181294                 Uli Hoene
# 19   1   73386  314467             SVG Reichenau
# 20   1  156040  744404      Mario Sergio Catala'
# 21   1   80536  349533         201112 Bundesliga
# 22   1  113888  510362       Stephan Beckenbauer
# 23   1  203375  901670                       Phl
# 24   1   61624  252651            Rumble Fighter
# 25   1   30425  120269                Gerd Mller
# 26   1    8128   27025               Gilli-danda
# 27   1  201546  895457            Luan Rodrigues
# 28   1  197370  879835              Bernd Nickel
# 29   1   52656  195267                Gary Twigg
# 30   1  198725  885321               Hohenlinden
# 31   1  105771  459770            UEFA Euro 2020
# 32   1   60720  247372              Thomas Mller
# 33   1  116414  527506              Klaas Bakker
# 34   1  143954  687624  Jean-Claude Schindelholz
# 35   1  129217  607474               Fritz Egner
# 36   1   68999  293186           Gerhard Tremmel
# 37   1  197137  878436          Pierre Kerkhoffs
# 38   1  182397  824496         Ugochukwu Oduenyi
# 39   1   56923  221228            Anthony Stokes
# 40   1  143943  687595               Fritz Knzli
# 41   1     576    2917                    Munich
# 42   1   46728  163153           Fernando Torres
# 43   1   55514  213649             Marcel Schfer
# 44   1  156497  745855            Emilio Caprile
# 45   1  199428  888424            Sandy Iannella
# 46   1  104184  454910            Enner Valencia
# 47   1  135851  649225         Batting (cricket)
# 48   1  122605  569592         Theo Brokmann Jr.
# 49   1  187039  840636          Bertil Johansson
#
#                                                   url  rank      score  \
# 0   https://simple.wikipedia.org/wiki/Mario%20Stri...     0  16.484302
# 1   https://simple.wikipedia.org/wiki/Mario%20Smas...     1  16.188615
# 2   https://simple.wikipedia.org/wiki/Audi%20Cup%2...     2  16.054922
# 3   https://simple.wikipedia.org/wiki/Alexander%20...     3  15.371080
# 4   https://simple.wikipedia.org/wiki/Princess%20D...     4  15.233306
# 5     https://simple.wikipedia.org/wiki/Donkey%20Kong     5  15.205449
# 6   https://simple.wikipedia.org/wiki/Princess%20P...     6  14.790709
# 7             https://simple.wikipedia.org/wiki/Yoshi     7  14.468759
# 8   https://simple.wikipedia.org/wiki/Mario%20Balo...     8  14.152757
# 9             https://simple.wikipedia.org/wiki/Luigi     9  13.449981
# 10            https://simple.wikipedia.org/wiki/Wario    10  13.104993
# 11   https://simple.wikipedia.org/wiki/Tobias%20Kempe    11  13.013470
# 12  https://simple.wikipedia.org/wiki/Audi%20Cup%2...    12  13.004589
# 13            https://simple.wikipedia.org/wiki/Mario    13  12.525434
# 14    https://simple.wikipedia.org/wiki/David%20Villa    14  12.396908
# 15  https://simple.wikipedia.org/wiki/Robert%20Lew...    15  12.242465
# 16  https://simple.wikipedia.org/wiki/Charles%20Ma...    16  11.810236
# 17  https://simple.wikipedia.org/wiki/2010%E2%80%9...    17  11.661661
# 18  https://simple.wikipedia.org/wiki/Uli%20Hoene%...    18  11.635518
# 19  https://simple.wikipedia.org/wiki/SVG%20Reichenau    19  11.628284
# 20  https://simple.wikipedia.org/wiki/Mario%20Serg...    20  11.523521
# 21  https://simple.wikipedia.org/wiki/2011%E2%80%9...    21  11.365680
# 22  https://simple.wikipedia.org/wiki/Stephan%20Be...    22  11.360023
# 23        https://simple.wikipedia.org/wiki/P%C3%A4hl    23  11.292779
# 24  https://simple.wikipedia.org/wiki/Rumble%20Fig...    24  11.219484
# 25  https://simple.wikipedia.org/wiki/Gerd%20M%C3%...    25  11.109520
# 26      https://simple.wikipedia.org/wiki/Gilli-danda    26  10.977289
# 27  https://simple.wikipedia.org/wiki/Luan%20Rodri...    27  10.950383
# 28   https://simple.wikipedia.org/wiki/Bernd%20Nickel    28  10.789584
# 29     https://simple.wikipedia.org/wiki/Gary%20Twigg    29  10.714612
# 30      https://simple.wikipedia.org/wiki/Hohenlinden    30  10.533918
# 31  https://simple.wikipedia.org/wiki/UEFA%20Euro%...    31  10.492153
# 32  https://simple.wikipedia.org/wiki/Thomas%20M%C...    32  10.456273
# 33   https://simple.wikipedia.org/wiki/Klaas%20Bakker    33  10.430601
# 34  https://simple.wikipedia.org/wiki/Jean-Claude%...    34  10.402867
# 35    https://simple.wikipedia.org/wiki/Fritz%20Egner    35  10.396753
# 36  https://simple.wikipedia.org/wiki/Gerhard%20Tr...    36  10.391642
# 37  https://simple.wikipedia.org/wiki/Pierre%20Ker...    37  10.359392
# 38  https://simple.wikipedia.org/wiki/Ugochukwu%20...    38  10.316130
# 39  https://simple.wikipedia.org/wiki/Anthony%20St...    39  10.313251
# 40  https://simple.wikipedia.org/wiki/Fritz%20K%C3...    40  10.309138
# 41           https://simple.wikipedia.org/wiki/Munich    41  10.307765
# 42  https://simple.wikipedia.org/wiki/Fernando%20T...    42  10.296484
# 43  https://simple.wikipedia.org/wiki/Marcel%20Sch...    43  10.196999
# 44  https://simple.wikipedia.org/wiki/Emilio%20Cap...    44  10.185687
# 45  https://simple.wikipedia.org/wiki/Sandy%20Iann...    45  10.185687
# 46  https://simple.wikipedia.org/wiki/Enner%20Vale...    46  10.168662
# 47  https://simple.wikipedia.org/wiki/Batting%20%2...    47  10.155964
# 48  https://simple.wikipedia.org/wiki/Theo%20Brokm...    48  10.137924
# 49  https://simple.wikipedia.org/wiki/Bertil%20Joh...    49  10.082568
#
#                                               query
# 0   Thomas and Mario are strikers playing in Munich
# 1   Thomas and Mario are strikers playing in Munich
# 2   Thomas and Mario are strikers playing in Munich
# 3   Thomas and Mario are strikers playing in Munich
# 4   Thomas and Mario are strikers playing in Munich
# 5   Thomas and Mario are strikers playing in Munich
# 6   Thomas and Mario are strikers playing in Munich
# 7   Thomas and Mario are strikers playing in Munich
# 8   Thomas and Mario are strikers playing in Munich
# 9   Thomas and Mario are strikers playing in Munich
# 10  Thomas and Mario are strikers playing in Munich
# 11  Thomas and Mario are strikers playing in Munich
# 12  Thomas and Mario are strikers playing in Munich
# 13  Thomas and Mario are strikers playing in Munich
# 14  Thomas and Mario are strikers playing in Munich
# 15  Thomas and Mario are strikers playing in Munich
# 16  Thomas and Mario are strikers playing in Munich
# 17  Thomas and Mario are strikers playing in Munich
# 18  Thomas and Mario are strikers playing in Munich
# 19  Thomas and Mario are strikers playing in Munich
# 20  Thomas and Mario are strikers playing in Munich
# 21  Thomas and Mario are strikers playing in Munich
# 22  Thomas and Mario are strikers playing in Munich
# 23  Thomas and Mario are strikers playing in Munich
# 24  Thomas and Mario are strikers playing in Munich
# 25  Thomas and Mario are strikers playing in Munich
# 26  Thomas and Mario are strikers playing in Munich
# 27  Thomas and Mario are strikers playing in Munich
# 28  Thomas and Mario are strikers playing in Munich
# 29  Thomas and Mario are strikers playing in Munich
# 30  Thomas and Mario are strikers playing in Munich
# 31  Thomas and Mario are strikers playing in Munich
# 32  Thomas and Mario are strikers playing in Munich
# 33  Thomas and Mario are strikers playing in Munich
# 34  Thomas and Mario are strikers playing in Munich
# 35  Thomas and Mario are strikers playing in Munich
# 36  Thomas and Mario are strikers playing in Munich
# 37  Thomas and Mario are strikers playing in Munich
# 38  Thomas and Mario are strikers playing in Munich
# 39  Thomas and Mario are strikers playing in Munich
# 40  Thomas and Mario are strikers playing in Munich
# 41  Thomas and Mario are strikers playing in Munich
# 42  Thomas and Mario are strikers playing in Munich
# 43  Thomas and Mario are strikers playing in Munich
# 44  Thomas and Mario are strikers playing in Munich
# 45  Thomas and Mario are strikers playing in Munich
# 46  Thomas and Mario are strikers playing in Munich
# 47  Thomas and Mario are strikers playing in Munich
# 48  Thomas and Mario are strikers playing in Munich
# 49  Thomas and Mario are strikers playing in Munich

# %%
pt.BatchRetrieve(indexref2, wmodel="Hiemstra_LM", metadata=["docno","title","url"]).search("Thomas and Mario are strikers playing in Munich").head(50)

# %% [markdown]
# ....
#
# ICI VOTRE RÉPONSE
#
# ....

# %% [markdown]
# # 3) Utilisation de termes
#
# Une stratégie consiste à utiliser individuellement chaque terme de la requête pour voir si vous arrivez à trouver les pages d’intérêt. Un code exemple est donné ci-dessous, cependant, il n'est pas suffisant pour faire la tâche.
#
# Proposer une modification de cette fonction basique (à vous de vous inspirer/inventer des modifications qui améliorent les résultats)
#
# Une fois fini votre code, réalisez la même vérification de résultats que dans le point précédent.

# %%
# MODIFIER CETTE FONCTION
def basic_term_search(query, method):
  termToSearch = [x for x in query.split() if x[0]==x[0].upper()]
  print(termToSearch)
  for term, page in zip(termToSearch,['Thomas Mller','Mario Gtze', 'FC Bayern Munich']):
    dfres = pt.BatchRetrieve(indexref2, wmodel=method, metadata=["docno","title","url"]).search(term)[['title','score']]
    print(dfres.head(10))
    print("Position de la page attendue dans les résultats :\n",dfres[dfres['title']==page],"\n\n\n")


query = "Thomas and Mario are strikers playing in Munich"
basic_term_search(query, "BM25")

# %%
# ICI VOTRE CODE POUR LA COMPARAISON
...

# %% [markdown]
# ....
#
# ICI VOTRE RÉPONSE
#
# ....

# %% [markdown]
# # 4) Le titre
# Maintenant utilisez le champ ***title*** avec la requête complète et avec chaque terme. Expliquez  pourquoi les résultats sont différents.

# %%
# ICI VOTRE CODE POUR CHARGER L'AUTRE INDEX
...

# %%
# ICI VOTRE CODE POUR LA COMPARAISON
...

# %% [markdown]
# ....
#
# ICI VOTRE RÉPONSE
#
# ....

# %% [markdown]
# # 5) L'outil
# Développez un outil/méthode/système capable de recevoir comme entrée un paragraphe de texte et comme sortie une liste ordonné de pages Wikipédia pour chaque unité lexical (token ou mot) dans le paragraphe.

# %% [markdown]
# ---
#
#
#
# En plus à l’information du TP, vous pouvez utiliser les ressources/idées suivants pour améliorer les résultats du système à développer :
# - La combinaison de plusieurs méthodes de pondération c’est possible en utilisant les indications sur https://pyterrier.readthedocs.io/en/latest/pipeline_examples.html .
# - Comme mentionné dans le TP1, il existe plusieurs type de champs. On a utilisé celui de la classe TextField. Renseignez vous sur les autres (StringField par exemple) et ses différences.
# - Les distances d’édition sont largement utilisés par les moteurs de recherche. Par exemple si vous tapez « paris sain germain » sur Google il va vous suggérer la requête « paris saint germain » l’équipe de football. Vous pouvez utiliser les distances d’édition pour trouver des entités avec une orthographe différent que celle sur Wikipédia. Une de distance très performantes est la distance Levenshtein implémentée dans la classe LuceneLevenshteinDistance du paquet lucene.search.spell.
# - Les moteurs de recherche peuvent être utilisés pour calculer la similarité entre les mots ou entre les entités. Par exemple, sur Google si vous tapez « orange » et « carrot » il y a plus de résultats que si vous tapez « purple » et « carrot ». Vous pouvez utiliser cette information pour décider si deux pages Wikipédia font partie d’un même sujet.
# - Utilisez le fichier [anchor_text_en.ttl](http://downloads.dbpedia.org/2015-10/core-i18n/en/anchor_text_en.ttl.bz2) qui contient les anchor texts  de la Wikipédia en anglais. Le format du fichier est décrit [ici](https://iai-group.github.io/DBpedia-Entity/index_details.html). Transformez-le dans ce format au autre similaire pour faire l'indexation:
#
# |             Frequency                 	|       Wikipedia Page        	| Anchor Text 	|
# |------------------------------	|---------------	|-----------	|
# |162| \<Saturn_Award_for_Best_Supporting_Actor> |"Best Supporting Actor"|
# |14 |\<André_Golke>| "Golke"|
# |13 |\<Charles_Pinckney_National_Historic_Site> |"Charles Pinckney National Historic Site"|
# |25 |\<Thomas_Manfredini>| "Manfredini"|
# |13 |<Marek_Zieńczuk> |"Marek Zieńczuk"|
# |14 |\<Sigurd_Ulveseth>| "Sigurd Ulveseth"|
# |104| <Pole_Position_(video_game)>| "Pole Position"|
# |10| <Bang_(band)>| "Bang"|
# |44| <George_Susce_(catcher)>| "George Susce"|
# |11| \<Kyle_Rankin>| "Kyle Rankin"|
# |…|…|…|
#
# Donc, la premier colonne correspond au nombre de fois que la chaîne de caractères de la troisième colonne a été utilisé pour faire allusion à la page Wikipédia de la deuxième colonne. C’est-à-dire que "Best Supporting Actor" a été utilisé 162 fois dans Wikipédia pour faire allusion à la page Wikipédia https://en.wikipedia.org/wiki/Saturn_Award_for_Best_Supporting_Actor . Le fichier anchor_text_en.tll  contient les informations de la Wikipédia en anglais et pas de la Wikipédia simple, donc certain titres n’ont pas de correspondance.

# %%
# ICI VOTRE CODE
